# %% [markdown]
# <a href="https://colab.research.google.com/github/rudalshan0412-code/Intent_Classifier-RAG_Chatbot/blob/main/00)_%ED%8C%8C%EC%9D%BC_%EC%83%9D%EC%84%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from pathlib import Path

# 1. Google Drive 연결
drive.mount("/content/drive")

# 2. 프로젝트 최상위 경로
PROJECT_ROOT = Path("/content/drive/MyDrive/rag_intent_chatbot")

# 3. 생성할 폴더
folders = [
    PROJECT_ROOT / "data" / "documents",
    PROJECT_ROOT / "models",
    PROJECT_ROOT / "src" / "intent",
    PROJECT_ROOT / "src" / "rag",
]

for folder in folders:
    folder.mkdir(parents=True, exist_ok=True)

# 4. 생성할 파일
files = [
    PROJECT_ROOT / "data" / "intents.json",
    PROJECT_ROOT / "data" / "documents" / "sample.txt",

    PROJECT_ROOT / "src" / "__init__.py",

    PROJECT_ROOT / "src" / "intent" / "__init__.py",
    PROJECT_ROOT / "src" / "intent" / "dataset.py",
    PROJECT_ROOT / "src" / "intent" / "model.py",
    PROJECT_ROOT / "src" / "intent" / "train.py",
    PROJECT_ROOT / "src" / "intent" / "predict.py",

    PROJECT_ROOT / "src" / "rag" / "__init__.py",
    PROJECT_ROOT / "src" / "rag" / "document_loader.py",
    PROJECT_ROOT / "src" / "rag" / "text_preprocessor.py",
    PROJECT_ROOT / "src" / "rag" / "chunker.py",
    PROJECT_ROOT / "src" / "rag" / "retriever.py",

    PROJECT_ROOT / "src" / "chatbot.py",
    PROJECT_ROOT / "main.py",
    PROJECT_ROOT / "requirements.txt",
]

for file_path in files:
    file_path.touch(exist_ok=True)

# 5. 현재 작업 폴더 변경
# %cd /content/drive/MyDrive/rag_intent_chatbot

# 6. 생성 결과 출력
print("\n프로젝트 생성 완료")
print(f"프로젝트 경로: {PROJECT_ROOT}\n")

for path in sorted(PROJECT_ROOT.rglob("*")):
    relative_path = path.relative_to(PROJECT_ROOT)
    depth = len(relative_path.parts) - 1
    indent = "    " * depth
    icon = "📁" if path.is_dir() else "📄"
    print(f"{indent}{icon} {path.name}")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/rag_intent_chatbot
#
# 프로젝트 생성 완료
# 프로젝트 경로: /content/drive/MyDrive/rag_intent_chatbot
#
# 📁 data
#     📁 documents
#         📄 sample.txt
#     📄 intents.json
# 📄 main.py
# 📁 models
# 📄 requirements.txt
# 📁 src
#     📄 __init__.py
#     📄 chatbot.py
#     📁 intent
#         📄 __init__.py
#         📄 dataset.py
#         📄 model.py
#         📄 predict.py
#         📄 train.py
#     📁 rag
#         📄 __init__.py
#         📄 chunker.py
#         📄 document_loader.py
#         📄 retriever.py
#         📄 text_preprocessor.py
